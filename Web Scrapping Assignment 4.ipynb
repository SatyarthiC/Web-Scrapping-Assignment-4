# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# Q1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
Rank=[]
Name=[] 
Artist=[]
Upload_date=[]
Views=[]

# %%
dt = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')
for d in dt:
    if d.text is None :
        Rank.append('-')
    else:
        Rank.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Name.append('-')
    else:
        Name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Artist.append('-')
    else:
        Artist.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        Upload_date.append('-')
    else:
        Upload_date.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Views.append('-')
    else:
        Views.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Rank']=Rank[:30]
table['Name']=Name[:30]
table['Artist']=Artist[:30]
table['Upload Date']=Upload_date[:30]
table['Views']=Views[:30]

table
# Out:
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[22]
# 1    2.                                  "Despacito"[24]
# 2    3.                               "Shape of You"[25]
# 3    4.                              "See You Again"[26]
# 4    5.                       "Johny Johny Yes Papa"[29]
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]
# 6    7.                                "Uptown Funk"[31]
# 7    8.                              "Gangnam Style"[32]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[34]
# 9   10.                                  "Bath Song"[35]
# 10  11.                "Phonics Song with Two Words"[36]
# 11  12.                                      "Sorry"[37]
# 12  13.                                      "Sugar"[38]
# 13  14.                                       "Roar"[39]
# 14  15.                             "Counting Stars"[40]
# ...

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://www.bcci.tv/')

# %%
dropdown = driver.find_element_by_xpath('//button[@class="navigation__header-button menu-button js-navigation-menu-button"]')
dropdown.click()

# %%
dropdown = driver.find_element_by_xpath('//div[@class="navigation__expand"]')
dropdown.click()

# %%
dropdown_enter = driver.find_element_by_xpath('//a[@href="/international/fixtures"]')
dropdown_enter.click()

# %%
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

# %%
dt = driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/strong')
for d in dt:
    Match_title.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="u-unskewed-text fixture__tournament-label u-truncated"]')
for d in dt:
    Series.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//p[@class="fixture__additional-info"]/span')
for d in dt:
    Place.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="fixture__time"]')
for d in dt:
    Time.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="fixture__datetime tablet-only"]/strong')
for d in dt:
    Date.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Match Title']=Match_title
table['Series']=Series
table['Place']=Place
table['Date']=Date
table['Time']=Time

# %%
table
# Out:
#    Match Title                Series  \
# 0     4th Test  INDIA V ENGLAND 2021
# 1     1st T20I  INDIA V ENGLAND 2021
# 2     2nd T20I  INDIA V ENGLAND 2021
# 3     3rd T20I  INDIA V ENGLAND 2021
# 4     4th T20I  INDIA V ENGLAND 2021
# 5     5th T20I  INDIA V ENGLAND 2021
# 6      1st ODI  INDIA V ENGLAND 2021
# 7      2nd ODI  INDIA V ENGLAND 2021
# 8      3rd ODI  INDIA V ENGLAND 2021
# 9     1st Test  ENGLAND V INDIA 2021
# 10    2nd Test  ENGLAND V INDIA 2021
# 11    3rd Test  ENGLAND V INDIA 2021
# 12    4th Test  ENGLAND V INDIA 2021
# 13    5th Test  ENGLAND V INDIA 2021
#
#                                             Place                  Date  \
# 0                Narendra Modi Stadium, Ahmedabad      Thursday 4 March
# 1                Narendra Modi Stadium, Ahmedabad       Friday 12 March
# 2                Narendra Modi Stadium, Ahmedabad       Sunday 14 March
# 3                Narendra Modi Stadium, Ahmedabad      Tuesday 16 March
# ...

# %% [markdown]
# Q3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://www.guru99.com/')

# %%
driver.find_element_by_xpath('//a[@title="Selenium"]').click()

# %%
driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()

# %%
Name=[]
Description=[]

# %%
dt = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for d in dt:
    Name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for d in dt:
    Description.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name[1:50]
table['Description']=Description[1:50]

table
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('http://statisticstimes.com/')

# %%
button=driver.find_elements_by_xpath('//div[@class="navbar"]/div[2]/div/a[3]')
button[0].click()

# %%
Rank=[]
State=[]
GSDP19_20=[]
GSDP18_19=[]
Share2018=[]
GDP_billion=[]

# %%
dt = driver.find_elements_by_xpath('//ul[@style="list-style-type:none;margin-left:20px;"]/li[1]')
dt[0].click()

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[1]')
for d in dt:
    Rank.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[2]')
for d in dt:
    State.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[3]')
for d in dt:
    GSDP19_20.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[4]')
for d in dt:
    GSDP18_19.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[5]')
for d in dt:
    Share2018.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@id="table_id"]/tbody/tr/td[6]')
for d in dt:
    GDP_billion.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Rank']=Rank
table['State']=State
table['GSDP(19-20)']=GSDP19_20
table['GSDP(18-19)']=GSDP18_19
table['Share(18-19)']=Share2018
table['GDP($billion)']=GDP_billion

table
# Out:
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.88%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.59%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.35%
# 3     4                    Gujarat           -   1,502,899        7.92%
# 4     5                  Karnataka   1,631,977   1,493,127        7.87%
# 5     6                West Bengal   1,253,832   1,089,898        5.75%
# 6     7                  Rajasthan   1,020,989     942,586        4.97%
# 7     8             Andhra Pradesh     972,782     862,957        4.55%
# 8     9                  Telangana     969,604     861,031        4.54%
# 9    10             Madhya Pradesh     906,672     809,592        4.27%
# 10   11                     Kerala           -     781,653        4.12%
# 11   12                      Delhi     856,112     774,870        4.08%
# ...

# %% [markdown]
# Q5.Scrape the details of trending repositories on Github.com. Url = https://github.com/ You have to find the following details: A) Repository title B) Repository description C) Contributors count D) Language used.

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://github.com/')

# %%
button=driver.find_elements_by_xpath('//div[@class="dropdown-menu flex-auto rounded-1 color-bg-primary px-0 pt-2 pb-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4"]/ul[2]/li[3]')
button[0].click()

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[] 
Language_used=[]

# %%
dt = driver.find_elements_by_xpath('//span[@class="text-normal"]')
for d in dt:
    if d.text is None :
        Repository_title.append('-')
    else:
        Repository_title.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//p[@class="col-9 color-text-secondary my-1 pr-4"]')
for d in dt:
    if d.text is None :
        Repository_description.append('-')
    else:
        Repository_description.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="f6 color-text-secondary mt-2"]/a[2]')
for d in dt:
    if d.text is None :
        Contributors_count.append('-')
    else:
        Contributors_count.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@itemprop="programmingLanguage"]')
for d in dt:    
    if d.text is None :
            Language_used.append('-') 
    else:
            Language_used.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Repository Title']=Repository_title[:22]
table['Repository Description']=Repository_description[:22]
table['Contributors Count']=Contributors_count[:22]
table['Language Used']=Language_used[:22]

table
# Out:
#        Repository Title                             Repository Description  \
# 0        muguruzawang /                                      优化版本的京东茅台抢购神器
# 1            tostercx /  The elegant TALL stack admin for Laravel artis...
# 2    laravel-filament /  PaddlePaddle GAN library, including lots of in...
# 3        PaddlePaddle /  A posix script to find and watch youtube video...
# 4          pystardust /           AWS SDK for the Go programming language.
# 5                 aws /  Googletest - Google Testing and Mocking Framework
# 6              google /  Demisto is now Cortex XSOAR. Automate and orch...
# 7             demisto /             Power Fx low-code programming language
# 8           microsoft /  24 Lessons, 12 Weeks, Get Started as a Web Dev...
# 9          bytemaster /  An open source code editor for the web, writte...
# 10          microsoft /                A curated list of engineering blogs
# ...

# %% [markdown]
# Q6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://www.billboard.com/')

# %%
button=driver.find_elements_by_xpath('//nav[@class="header__subnav bg--light"]/ul/li[3]/a')
button[0].click()

# %%
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %%
dt = driver.find_elements_by_xpath('//span[@class="chart-element__information__song text--truncate color--primary"]')
for d in dt:
    if d.text is None :
        Song_name.append('-')
    else:
        Song_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="chart-element__information__artist text--truncate color--secondary"]')
for d in dt:
    if d.text is None :
        Artist_name.append('-')
    else:
        Artist_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--last"]')
for d in dt:
    if d.text is None :
        Last_week_rank.append('-')
    else:
        Last_week_rank.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--peak"]')
for d in dt:
    if d.text is None :
        Peak_rank.append('-')
    else:
        Peak_rank.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="chart-element__meta text--center color--secondary text--week"]')
for d in dt:
    if d.text is None :
        Weeks_on_board.append('-')
    else:
        Weeks_on_board.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Song Name']=Song_name
table['Artist Name']=Artist_name
table['Last Week Rank']=Last_week_rank
table['Peak Rank']=Peak_rank
table['Weeks On Board']=Weeks_on_board

table
# Out:
#           Song Name                                 Artist Name  \
# 0   Drivers License                              Olivia Rodrigo
# 1                Up                                     Cardi B
# 2          Go Crazy                    Chris Brown & Young Thug
# 3             34+35                               Ariana Grande
# 4   Blinding Lights                                  The Weeknd
# ..              ...                                         ...
# 95     The Business                                      Tiesto
# 96            Hello  Pop Smoke Featuring A Boogie Wit da Hoodie
# 97          Monster                Shawn Mendes & Justin Bieber
# 98       Track Star                                      Mooski
# 99  Like I Want You                                      Giveon
#
#    Last Week Rank Peak Rank Weeks On Board
# 0               1         1              7
# 1               5         2              3
# 2               8         3             42
# ...

# %% [markdown]
# Q7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get(' https://www.naukri.com/')

# %%
button=driver.find_elements_by_xpath('//ul[@class="midSec menu"]/li[2]')
button[0].click()

# %%
driver.switch_to.window(driver.window_handles[1])

# %%
search_job = driver.find_element_by_xpath("//input[@class='sugInp']")
search_job.send_keys("Data science")
search_btn = driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search_btn.click()

# %%
Name=[]
Designation=[]
Company=[]
Skills_required=[]
Location=[]

# %%
for page in range(0,120):
    
    dt = driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
    for d in dt:
        if d.text is None :
            Name.append('-')
        else:
            Name.append(d.text)
            
    dt = driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
    for d in dt:
        if d.text is None :
            Designation.append('-')
        else:
            Designation.append(d.text)        
    
    dt = driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
    for d in dt:
        if d.text is None :
            Company.append('-')
        else:
            Company.append(d.text)
            
    dt = driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
    for d in dt:
        if d.text is None :
            Skills_required.append('-')
        else:
            Skills_required.append(d.text)       
            
    dt = driver.find_elements_by_xpath('//small[@class="ellipsis"]')
    for d in dt:
        if d.text is None :
            Location.append('-')
        else:
            Location.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name[:8000]
table['Designation']=Designation[:8000]
table['Company']=Company[:8000]
table['Skills they hire for']=Skills_required[:8000]
table['Location']=Location[:8000]

table
# Out:
#                          Name                    Designation  \
# 0                Rashi Kacker             Sr Product Manager
# 1                  Shailaja.N              Company Recruiter
# 2                     Ashwini       Director Global Delivery
# 3         vidya bhushan singh                         jaipur
# 4                Balaji Kolli                     Co Founder
# ...                       ...                            ...
# 7995              Mamta Rawat            Technical Recruiter
# 7996                  Pradeep                       Director
# 7997  Naga Deepika AlgoSquare                  Consultant HR
# 7998       Vanitha Senkurichi                     Company HR
# 7999          Hansraj B Surti  Talent Acquisition Specialist
#
#                                      Company  \
# 0                       Impel Labs Pvt. Ltd.
# 1     Kigyan School of Data Science Pvt.Ltd.
# 2                               MRP Advisers
# 3                          Next Data Science
# ...

# %% [markdown]
# Q8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Book_name.append('-')
    else:
        Book_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Author_name.append('-')
    else:
        Author_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Volumes_sold.append('-')
    else:
        Volumes_sold.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        Publisher.append('-')
    else:
        Publisher.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
for d in dt:
    if d.text is None :
        Genre.append('-')
    else:
        Genre.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Book Name']=Book_name
table['Author Name']=Author_name
table['Volumes Sold']=Volumes_sold
table['Publisher']=Publisher
table['Genre']=Genre

table
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# ...

# %% [markdown]
# Q9.Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://www.imdb.com/list/ls095964455/')

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[] 
Ratings=[]
Votes=[]

# %%
dt = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
for d in dt:
    if d.text is None :
        Name.append('-')
    else:
        Name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
for d in dt:
    if d.text is None :
        Year_span.append('-')
    else:
        Year_span.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="genre"]')
for d in dt:
    if d.text is None :
        Genre.append('-')
    else:
        Genre.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@class="runtime"]')
for d in dt:
    if d.text is None :
        Run_time.append('-')
    else:
        Run_time.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]/span[2]')
for d in dt:
    if d.text is None :
        Ratings.append('-')
    else:
        Ratings.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//span[@name="nv"]')
for d in dt:
    if d.text is None :
        Votes.append('-')
    else:
        Votes.append(d.text)

# %%
import pandas as pd
table=pd.DataFrame({})

table['Name']=Name
table['Year Span']=Year_span
table['Genre']=Genre
table['Run Time']=Run_time
table['Votes']=Votes

table
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead     (2010– )   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Crime, Drama, Horror
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time      Votes
# 0    57 min  1,777,845
# 1    51 min    828,495
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver = webdriver.Chrome("C:/Users/CHITRAK/Downloads/chromedriver.exe")

# %%
driver.get('https://archive.ics.uci.edu/ml/index.php')

# %%
d = driver.find_element_by_xpath('//span[@class="normal"]/b')
d.click()

# %%
Dataset_name=[]
Data_type=[]
Task=[]
Attribute_type=[]
instances=[]
attribute=[]
Year=[]

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b')
for d in dt:
    if d.text is None :
        Dataset_name.append('-')
    else:
        Dataset_name.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[2]')
for d in dt:
    if d.text is None :
        Data_type.append('-')
    else:
        Data_type.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[3]')
for d in dt:
    if d.text is None :
        Task.append('-')
    else:
        Task.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[4]')
for d in dt:
    if d.text is None :
        Attribute_type.append('-')
    else:
        Attribute_type.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[5]')
for d in dt:
    if d.text is None :
        instances.append('-')
    else:
        instances.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[6]')
for d in dt:
    if d.text is None :
        attribute.append('-')
    else:
        attribute.append(d.text)

# %%
dt = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr/td[7]')
for d in dt:
    if d.text is None :
        Year.append('-')
    else:
        Year.append(d.text)

# %%
print(len(Dataset_name))
print(len(Data_type))
print(len(Task))
print(len(Attribute_type))
print(len(instances))
print(len(attribute))
print(len(Year))
# Out:
# 585
# 586
# 586
# 586
# 586
# 586
# 586

# %%
import pandas as pd
table=pd.DataFrame({})

table['Dataset Name']=Dataset_name
table['Data Type']=Data_type[1:586]
table['Task']=Task[1:586]
table['Attribute Type']=Attribute_type[1:586]
table['Instances']=instances[1:586]
table['Attribute']=attribute[1:586]
table['Year']=Year[1:586]


table
# Out:
#                                  Dataset Name                   Data Type  \
# 0                                     Abalone               Multivariate
# 1                                       Adult               Multivariate
# 2                                   Annealing               Multivariate
# 3                Anonymous Microsoft Web Data
# 4                                  Arrhythmia               Multivariate
# ..                                        ...                         ...
# 580                Wisesight Sentiment Corpus         Multivariate, Text
# 581  AI4I 2020 Predictive Maintenance Dataset  Multivariate, Time-Series
# 582                          Dry Bean Dataset               Multivariate
# 583          in-vehicle coupon recommendation               Multivariate
# 584                       Gait Classification               Multivariate
#
#                                               Task  \
# 0                                  Classification
# ...
